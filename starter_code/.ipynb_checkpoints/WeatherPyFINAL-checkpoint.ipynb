# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
weather_api_key = "IMPORT API KEY... I had to purchase it for it to work"

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 614

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "IMPORT YOUR WEATHER API"



# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city

    city_url = url + '&q=' + city 

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
       

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather ["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | yarmouth
# Processing Record 3 of Set 1 | bar-le-duc
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | port hardy
# Processing Record 6 of Set 1 | humaita
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | shingu
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | ihosy
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | klyuchi
# Processing Record 14 of Set 1 | orlik
# Processing Record 15 of Set 1 | te anau
# Processing Record 16 of Set 1 | lokosovo
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | yulara
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | altar
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | lorengau
# Processing Record 26 of Set 1 | cochrane
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | kahului
# Processing Record 30 of Set 1 | watsa
# Processing Record 31 of Set 1 | vila franca do campo
# Processing Record 32 of Set 1 | puerto princesa
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | nisia floresta
# Processing Record 38 of Set 1 | pacific grove
# Processing Record 39 of Set 1 | saldanha
# Processing Record 40 of Set 1 | nemuro
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | bilibino
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 0 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | aykhal
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | mahebourg
# Processing Record 7 of Set 2 | mehamn
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | mikhaylovka
# Processing Record 13 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | marsh harbour
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | weinan
# Processing Record 18 of Set 2 | balabac
# Processing Record 19 of Set 2 | anajatuba
# Processing Record 20 of Set 2 | wewak
# Processing Record 21 of Set 2 | tlahualilo
# City not found. Skipping...
# Processing Record 22 of Set 2 | hof
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | esperance
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | dingle
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | gravdal
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | ponta delgada
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | shihezi
# Processing Record 35 of Set 2 | clyde river
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | petatlan
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | evensk
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | hofn
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | busselton
# Processing Record 46 of Set 2 | okha
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | nome
# Processing Record 49 of Set 2 | uporovo
# Processing Record 0 of Set 3 | faanui
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | marawi
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | junagarh
# Processing Record 5 of Set 3 | henties bay
# Processing Record 6 of Set 3 | vanimo
# Processing Record 7 of Set 3 | shenjiamen
# Processing Record 8 of Set 3 | ingham
# Processing Record 9 of Set 3 | smithers
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | zeya
# Processing Record 14 of Set 3 | quepos
# Processing Record 15 of Set 3 | vrangel
# Processing Record 16 of Set 3 | fallon
# Processing Record 17 of Set 3 | formosa
# Processing Record 18 of Set 3 | yumen
# Processing Record 19 of Set 3 | san francisco del mar
# Processing Record 20 of Set 3 | kyren
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | talcahuano
# Processing Record 23 of Set 3 | provideniya
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | ilulissat
# Processing Record 26 of Set 3 | dharchula
# Processing Record 27 of Set 3 | kapiri mposhi
# Processing Record 28 of Set 3 | mareeba
# Processing Record 29 of Set 3 | gwadar
# Processing Record 30 of Set 3 | xinyang
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | owando
# Processing Record 33 of Set 3 | sampit
# Processing Record 34 of Set 3 | rio gallegos
# Processing Record 35 of Set 3 | cervo
# Processing Record 36 of Set 3 | husavik
# Processing Record 37 of Set 3 | viedma
# Processing Record 38 of Set 3 | narsaq
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | menongue
# Processing Record 41 of Set 3 | homer
# Processing Record 42 of Set 3 | gazli
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | fortuna
# Processing Record 45 of Set 3 | batemans bay
# Processing Record 46 of Set 3 | kumluca
# Processing Record 47 of Set 3 | ongandjera
# Processing Record 48 of Set 3 | bilma
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 0 of Set 4 | coffs harbour
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | shasta lake
# Processing Record 3 of Set 4 | sao jose da coroa grande
# Processing Record 4 of Set 4 | cap malheureux
# Processing Record 5 of Set 4 | tual
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | broken hill
# Processing Record 8 of Set 4 | innisfail
# Processing Record 9 of Set 4 | sayyan
# Processing Record 10 of Set 4 | alpena
# Processing Record 11 of Set 4 | nantucket
# Processing Record 12 of Set 4 | kassala
# Processing Record 13 of Set 4 | jackson
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | lagoa
# Processing Record 19 of Set 4 | comodoro rivadavia
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | plyussa
# Processing Record 22 of Set 4 | terrace bay
# Processing Record 23 of Set 4 | manta
# Processing Record 24 of Set 4 | korla
# Processing Record 25 of Set 4 | maromitsa
# Processing Record 26 of Set 4 | san cristobal
# Processing Record 27 of Set 4 | multan
# Processing Record 28 of Set 4 | palana
# Processing Record 29 of Set 4 | alvaraes
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | carupano
# Processing Record 32 of Set 4 | port moresby
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | sur
# Processing Record 35 of Set 4 | sosnovo-ozerskoye
# Processing Record 36 of Set 4 | nioro
# Processing Record 37 of Set 4 | abha
# Processing Record 38 of Set 4 | ossora
# Processing Record 39 of Set 4 | fez
# Processing Record 40 of Set 4 | kilembe
# Processing Record 41 of Set 4 | puri
# Processing Record 42 of Set 4 | yatou
# Processing Record 43 of Set 4 | vostok
# Processing Record 44 of Set 4 | sorland
# Processing Record 45 of Set 4 | mlonggo
# Processing Record 46 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 4 | nanortalik
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | codrington
# Processing Record 0 of Set 5 | victor harbor
# Processing Record 1 of Set 5 | honavar
# Processing Record 2 of Set 5 | roebourne
# Processing Record 3 of Set 5 | beloha
# Processing Record 4 of Set 5 | tshikapa
# Processing Record 5 of Set 5 | zaragoza
# Processing Record 6 of Set 5 | okhotsk
# Processing Record 7 of Set 5 | chifeng
# Processing Record 8 of Set 5 | lao cai
# Processing Record 9 of Set 5 | kasongo-lunda
# Processing Record 10 of Set 5 | bandarbeyla
# Processing Record 11 of Set 5 | noyabrsk
# Processing Record 12 of Set 5 | constitucion
# Processing Record 13 of Set 5 | olafsvik
# Processing Record 14 of Set 5 | bayangol
# Processing Record 15 of Set 5 | ostrovnoy
# Processing Record 16 of Set 5 | sangar
# Processing Record 17 of Set 5 | chokurdakh
# Processing Record 18 of Set 5 | angola
# Processing Record 19 of Set 5 | mahe
# Processing Record 20 of Set 5 | havoysund
# Processing Record 21 of Set 5 | jaciara
# Processing Record 22 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 5 | pochutla
# Processing Record 24 of Set 5 | sola
# Processing Record 25 of Set 5 | kavieng
# Processing Record 26 of Set 5 | zhigalovo
# Processing Record 27 of Set 5 | acari
# Processing Record 28 of Set 5 | tinogboc
# Processing Record 29 of Set 5 | lebu
# Processing Record 30 of Set 5 | agadez
# Processing Record 31 of Set 5 | khani
# Processing Record 32 of Set 5 | auki
# Processing Record 33 of Set 5 | leh
# Processing Record 34 of Set 5 | salalah
# Processing Record 35 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 5 | chuy
# Processing Record 37 of Set 5 | tiksi
# Processing Record 38 of Set 5 | bengkulu
# Processing Record 39 of Set 5 | kisangani
# Processing Record 40 of Set 5 | kruisfontein
# Processing Record 41 of Set 5 | dandong
# Processing Record 42 of Set 5 | nikolayevsk-na-amure
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | cayenne
# Processing Record 45 of Set 5 | maneromango
# Processing Record 46 of Set 5 | asau
# Processing Record 47 of Set 5 | rocha
# Processing Record 48 of Set 5 | obo
# Processing Record 49 of Set 5 | mushie
# Processing Record 0 of Set 6 | cockburn town
# Processing Record 1 of Set 6 | kupang
# Processing Record 2 of Set 6 | ketchikan
# Processing Record 3 of Set 6 | erbaa
# Processing Record 4 of Set 6 | lagunas
# Processing Record 5 of Set 6 | raudeberg
# Processing Record 6 of Set 6 | kodiak
# Processing Record 7 of Set 6 | olinda
# Processing Record 8 of Set 6 | ekhabi
# Processing Record 9 of Set 6 | tarakan
# Processing Record 10 of Set 6 | bubaque
# Processing Record 11 of Set 6 | irbeyskoye
# Processing Record 12 of Set 6 | yining
# Processing Record 13 of Set 6 | matsanga
# City not found. Skipping...
# Processing Record 14 of Set 6 | cidreira
# Processing Record 15 of Set 6 | carutapera
# Processing Record 16 of Set 6 | boyolangu
# Processing Record 17 of Set 6 | tenkodogo
# Processing Record 18 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 6 | bokoro
# Processing Record 20 of Set 6 | arraial do cabo
# Processing Record 21 of Set 6 | trat
# Processing Record 22 of Set 6 | praia
# Processing Record 23 of Set 6 | kalmunai
# Processing Record 24 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 6 | the valley
# Processing Record 26 of Set 6 | college
# Processing Record 27 of Set 6 | luanda
# Processing Record 28 of Set 6 | hirara
# Processing Record 29 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 30 of Set 6 | longonjo
# Processing Record 31 of Set 6 | samarai
# Processing Record 32 of Set 6 | fantino
# Processing Record 33 of Set 6 | whithorn
# Processing Record 34 of Set 6 | las matas de farfan
# Processing Record 35 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 6 | nanning
# Processing Record 37 of Set 6 | jonava
# Processing Record 38 of Set 6 | camacha
# Processing Record 39 of Set 6 | acapulco
# Processing Record 40 of Set 6 | caxito
# Processing Record 41 of Set 6 | ayagoz
# Processing Record 42 of Set 6 | golfito
# Processing Record 43 of Set 6 | beringovskiy
# Processing Record 44 of Set 6 | komsomolskiy
# Processing Record 45 of Set 6 | jumla
# Processing Record 46 of Set 6 | doha
# Processing Record 47 of Set 6 | berlevag
# Processing Record 48 of Set 6 | khipro
# Processing Record 49 of Set 6 | muros
# Processing Record 0 of Set 7 | fairlie
# Processing Record 1 of Set 7 | barranca
# Processing Record 2 of Set 7 | barra patuca
# Processing Record 3 of Set 7 | baruun-urt
# Processing Record 4 of Set 7 | katherine
# Processing Record 5 of Set 7 | ucluelet
# Processing Record 6 of Set 7 | gladstone
# Processing Record 7 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 8 of Set 7 | fairbanks
# Processing Record 9 of Set 7 | hervey bay
# Processing Record 10 of Set 7 | meulaboh
# Processing Record 11 of Set 7 | takaka
# Processing Record 12 of Set 7 | santa isabel do rio negro
# Processing Record 13 of Set 7 | isangel
# Processing Record 14 of Set 7 | mount isa
# Processing Record 15 of Set 7 | mandalgovi
# Processing Record 16 of Set 7 | broome
# Processing Record 17 of Set 7 | mount gambier
# Processing Record 18 of Set 7 | finnsnes
# Processing Record 19 of Set 7 | hammerfest
# Processing Record 20 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 7 | kalabo
# Processing Record 22 of Set 7 | saint-philippe
# Processing Record 23 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 7 | itarema
# Processing Record 25 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 26 of Set 7 | richards bay
# Processing Record 27 of Set 7 | pevek
# Processing Record 28 of Set 7 | sitka
# Processing Record 29 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 7 | hasaki
# Processing Record 31 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 7 | leningradskiy
# Processing Record 33 of Set 7 | rio grande
# Processing Record 34 of Set 7 | kampong cham
# Processing Record 35 of Set 7 | borogontsy
# Processing Record 36 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 7 | ambovombe
# Processing Record 38 of Set 7 | ponta do sol
# Processing Record 39 of Set 7 | blairmore
# Processing Record 40 of Set 7 | riyadh
# Processing Record 41 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | martinsicuro
# Processing Record 44 of Set 7 | tabora
# Processing Record 45 of Set 7 | bahia honda
# Processing Record 46 of Set 7 | berezovyy
# Processing Record 47 of Set 7 | kaeo
# Processing Record 48 of Set 7 | jalalpur
# Processing Record 49 of Set 7 | villazon
# Processing Record 0 of Set 8 | bukama
# Processing Record 1 of Set 8 | liverpool
# Processing Record 2 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 4 of Set 8 | talnakh
# Processing Record 5 of Set 8 | odweyne
# Processing Record 6 of Set 8 | camana
# Processing Record 7 of Set 8 | neiafu
# Processing Record 8 of Set 8 | filadelfia
# Processing Record 9 of Set 8 | cururupu
# Processing Record 10 of Set 8 | rampura
# Processing Record 11 of Set 8 | grindavik
# Processing Record 12 of Set 8 | romny
# Processing Record 13 of Set 8 | glossa
# Processing Record 14 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 15 of Set 8 | kavaratti
# Processing Record 16 of Set 8 | port-gentil
# Processing Record 17 of Set 8 | xining
# Processing Record 18 of Set 8 | santa rosa
# Processing Record 19 of Set 8 | hobyo
# Processing Record 20 of Set 8 | dalvik
# Processing Record 21 of Set 8 | alihe
# Processing Record 22 of Set 8 | pamekasan
# Processing Record 23 of Set 8 | ust-koksa
# Processing Record 24 of Set 8 | celestun
# Processing Record 25 of Set 8 | kieta
# Processing Record 26 of Set 8 | kenai
# Processing Record 27 of Set 8 | waingapu
# Processing Record 28 of Set 8 | chkalovskoye
# Processing Record 29 of Set 8 | iqaluit
# Processing Record 30 of Set 8 | derzhavinsk
# Processing Record 31 of Set 8 | haines junction
# Processing Record 32 of Set 8 | azul
# Processing Record 33 of Set 8 | coahuayana
# Processing Record 34 of Set 8 | la paz
# Processing Record 35 of Set 8 | ambon
# Processing Record 36 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 8 | ovalle
# Processing Record 38 of Set 8 | perry
# Processing Record 39 of Set 8 | vallenar
# Processing Record 40 of Set 8 | coquimbo
# Processing Record 41 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 42 of Set 8 | krasnoselkup
# Processing Record 43 of Set 8 | norman wells
# Processing Record 44 of Set 8 | caravelas
# Processing Record 45 of Set 8 | padang
# Processing Record 46 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 47 of Set 8 | andenes
# Processing Record 48 of Set 8 | tuatapere
# Processing Record 49 of Set 8 | jijiga
# Processing Record 0 of Set 9 | shache
# Processing Record 1 of Set 9 | ayan
# Processing Record 2 of Set 9 | waitati
# Processing Record 3 of Set 9 | sistranda
# Processing Record 4 of Set 9 | kismayo
# Processing Record 5 of Set 9 | skanevik
# City not found. Skipping...
# Processing Record 6 of Set 9 | luba
# Processing Record 7 of Set 9 | damghan
# Processing Record 8 of Set 9 | niksar
# Processing Record 9 of Set 9 | vestmannaeyjar
# Processing Record 10 of Set 9 | arlit
# Processing Record 11 of Set 9 | mamallapuram
# Processing Record 12 of Set 9 | south lake tahoe
# Processing Record 13 of Set 9 | ouargaye
# Processing Record 14 of Set 9 | yar-sale
# Processing Record 15 of Set 9 | kathmandu
# Processing Record 16 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 9 | chimbote
# Processing Record 18 of Set 9 | sungaipenuh
# Processing Record 19 of Set 9 | faya
# Processing Record 20 of Set 9 | pangody
# Processing Record 21 of Set 9 | dortyol
# Processing Record 22 of Set 9 | rengo
# Processing Record 23 of Set 9 | pisco
# Processing Record 24 of Set 9 | alberton
# Processing Record 25 of Set 9 | tessalit
# Processing Record 26 of Set 9 | airai
# Processing Record 27 of Set 9 | kardailovo
# Processing Record 28 of Set 9 | fort saint james
# Processing Record 29 of Set 9 | faribault
# Processing Record 30 of Set 9 | buin
# Processing Record 31 of Set 9 | lata
# Processing Record 32 of Set 9 | santiago
# Processing Record 33 of Set 9 | hopelchen
# Processing Record 34 of Set 9 | orito
# Processing Record 35 of Set 9 | maun
# Processing Record 36 of Set 9 | pahrump
# Processing Record 37 of Set 9 | aguilar de la frontera
# Processing Record 38 of Set 9 | sao filipe
# Processing Record 39 of Set 9 | karaton
# Processing Record 40 of Set 9 | quelimane
# Processing Record 41 of Set 9 | hvide sande
# Processing Record 42 of Set 9 | northam
# Processing Record 43 of Set 9 | balakhninskiy
# Processing Record 44 of Set 9 | nyzhnya duvanka
# Processing Record 45 of Set 9 | mount darwin
# Processing Record 46 of Set 9 | westport
# Processing Record 47 of Set 9 | hallingby
# City not found. Skipping...
# Processing Record 48 of Set 9 | pyay
# Processing Record 49 of Set 9 | drayton valley
# Processing Record 0 of Set 10 | san isidro
# Processing Record 1 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 10 | sisimiut
# Processing Record 3 of Set 10 | domnesti
# Processing Record 4 of Set 10 | kurumkan
# Processing Record 5 of Set 10 | ducheng
# Processing Record 6 of Set 10 | mingaora
# Processing Record 7 of Set 10 | shurob
# Processing Record 8 of Set 10 | nizhniy odes
# Processing Record 9 of Set 10 | diego de almagro
# Processing Record 10 of Set 10 | sinnamary
# Processing Record 11 of Set 10 | penzance
# Processing Record 12 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 13 of Set 10 | heze
# Processing Record 14 of Set 10 | santa isabel
# Processing Record 15 of Set 10 | izumo
# Processing Record 16 of Set 10 | skage
# City not found. Skipping...
# Processing Record 17 of Set 10 | coruripe
# Processing Record 18 of Set 10 | pineville
# Processing Record 19 of Set 10 | baykit
# Processing Record 20 of Set 10 | altos
# Processing Record 21 of Set 10 | tuy hoa
# Processing Record 22 of Set 10 | harper
# Processing Record 23 of Set 10 | ozinki
# Processing Record 24 of Set 10 | guanica
# Processing Record 25 of Set 10 | pombia
# Processing Record 26 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 10 | tucuman
# Processing Record 28 of Set 10 | mizdah
# Processing Record 29 of Set 10 | antalaha
# Processing Record 30 of Set 10 | novoagansk
# Processing Record 31 of Set 10 | khobi
# Processing Record 32 of Set 10 | marsabit
# Processing Record 33 of Set 10 | muskegon
# Processing Record 34 of Set 10 | katsuura
# Processing Record 35 of Set 10 | tateyama
# Processing Record 36 of Set 10 | tura
# Processing Record 37 of Set 10 | jiangyou
# Processing Record 38 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 10 | taltal
# Processing Record 40 of Set 10 | sergeyevka
# Processing Record 41 of Set 10 | port lincoln
# Processing Record 42 of Set 10 | waddan
# Processing Record 43 of Set 10 | boa vista
# Processing Record 44 of Set 10 | beyneu
# Processing Record 45 of Set 10 | kihei
# Processing Record 46 of Set 10 | luwingu
# Processing Record 47 of Set 10 | morondava
# Processing Record 48 of Set 10 | buchanan
# Processing Record 49 of Set 10 | kishi
# Processing Record 0 of Set 11 | hlotse
# Processing Record 1 of Set 11 | vanavara
# Processing Record 2 of Set 11 | upington
# Processing Record 3 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 11 | boden
# Processing Record 5 of Set 11 | cangucu
# Processing Record 6 of Set 11 | nago
# Processing Record 7 of Set 11 | warkworth
# Processing Record 8 of Set 11 | tahta
# Processing Record 9 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 11 | hovd
# Processing Record 11 of Set 11 | inverell
# Processing Record 12 of Set 11 | chajul
# Processing Record 13 of Set 11 | lodeynoye pole
# Processing Record 14 of Set 11 | chardara
# Processing Record 15 of Set 11 | adrar
# Processing Record 16 of Set 11 | arman
# Processing Record 17 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 18 of Set 11 | poum
# Processing Record 19 of Set 11 | mtwara
# Processing Record 20 of Set 11 | tadine
# Processing Record 21 of Set 11 | tilichiki
# Processing Record 22 of Set 11 | sarrebourg
# Processing Record 23 of Set 11 | scottsbluff
# Processing Record 24 of Set 11 | takoradi
# Processing Record 25 of Set 11 | mackay
# Processing Record 26 of Set 11 | marsa matruh
# Processing Record 27 of Set 11 | powell river
# Processing Record 28 of Set 11 | villerupt
# Processing Record 29 of Set 11 | tabuk
# Processing Record 30 of Set 11 | nacala
# Processing Record 31 of Set 11 | paranagua
# Processing Record 32 of Set 11 | konstantinovka
# Processing Record 33 of Set 11 | stettler
# Processing Record 34 of Set 11 | amurzet
# Processing Record 35 of Set 11 | roth
# Processing Record 36 of Set 11 | nhulunbuy
# Processing Record 37 of Set 11 | nogliki
# Processing Record 38 of Set 11 | carballo
# Processing Record 39 of Set 11 | port shepstone
# Processing Record 40 of Set 11 | hebertville
# City not found. Skipping...
# Processing Record 41 of Set 11 | guerrero negro
# Processing Record 42 of Set 11 | namibe
# Processing Record 43 of Set 11 | kununurra
# Processing Record 44 of Set 11 | suleya
# Processing Record 45 of Set 11 | san pedro
# Processing Record 46 of Set 11 | predivinsk
# Processing Record 47 of Set 11 | upata
# Processing Record 48 of Set 11 | vila velha
# Processing Record 49 of Set 11 | dovolnoye
# Processing Record 0 of Set 12 | greensburg
# Processing Record 1 of Set 12 | vanderhoof
# Processing Record 2 of Set 12 | ukiah
# Processing Record 3 of Set 12 | sabzevar
# Processing Record 4 of Set 12 | sidi ali
# Processing Record 5 of Set 12 | lakes entrance
# Processing Record 6 of Set 12 | chiclana
# Processing Record 7 of Set 12 | portland
# Processing Record 8 of Set 12 | whitianga
# Processing Record 9 of Set 12 | pangai
# Processing Record 10 of Set 12 | ranong
# Processing Record 11 of Set 12 | qaqortoq
# Processing Record 12 of Set 12 | kristiinankaupunki
# Processing Record 13 of Set 12 | presidencia roque saenz pena
# Processing Record 14 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 12 | atlantis
# Processing Record 16 of Set 12 | lazaro cardenas
# Processing Record 17 of Set 12 | amahai
# Processing Record 18 of Set 12 | kamaishi
# Processing Record 19 of Set 12 | souillac
# Processing Record 20 of Set 12 | ulsteinvik
# Processing Record 21 of Set 12 | torres
# Processing Record 22 of Set 12 | jinka
# Processing Record 23 of Set 12 | plerin
# Processing Record 24 of Set 12 | vao
# Processing Record 25 of Set 12 | karratha
# Processing Record 26 of Set 12 | praia da vitoria
# Processing Record 27 of Set 12 | rundu
# Processing Record 28 of Set 12 | athabasca
# Processing Record 29 of Set 12 | novosokolniki
# Processing Record 30 of Set 12 | sambava
# Processing Record 31 of Set 12 | henzada
# City not found. Skipping...
# Processing Record 32 of Set 12 | zhanaozen
# Processing Record 33 of Set 12 | gebre guracha
# Processing Record 34 of Set 12 | sakakah
# Processing Record 35 of Set 12 | kondinskoye
# Processing Record 36 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 37 of Set 12 | uyskoye
# Processing Record 38 of Set 12 | shirokiy
# Processing Record 39 of Set 12 | bonthe
# Processing Record 40 of Set 12 | duz
# City not found. Skipping...
# Processing Record 41 of Set 12 | sao joao da barra
# Processing Record 42 of Set 12 | puerto narino
# Processing Record 43 of Set 12 | illela
# Processing Record 44 of Set 12 | tres lagoas
# Processing Record 45 of Set 12 | kropotkin
# Processing Record 46 of Set 12 | qasigiannguit
# Processing Record 47 of Set 12 | la romana
# Processing Record 48 of Set 12 | tiarei
# Processing Record 49 of Set 12 | punta de bombon
# Processing Record 0 of Set 13 | canmore
# Processing Record 1 of Set 13 | pascagoula
# Processing Record 2 of Set 13 | wa
# City not found. Skipping...
# Processing Record 3 of Set 13 | ahipara
# Processing Record 4 of Set 13 | synya
# Processing Record 5 of Set 13 | nelson bay
# Processing Record 6 of Set 13 | steamboat springs
# Processing Record 7 of Set 13 | rosario
# Processing Record 8 of Set 13 | katy
# Processing Record 9 of Set 13 | mehran
# Processing Record 10 of Set 13 | winchester
# Processing Record 11 of Set 13 | vila do maio
# Processing Record 12 of Set 13 | alofi
# Processing Record 13 of Set 13 | san carlos de bariloche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0             port elizabeth -33.9180   25.5701     63.10        77
# 1                   yarmouth  41.7057  -70.2286     57.96        56
# 2                 bar-le-duc  48.7500    5.1667     42.22        95
# 3                  hithadhoo  -0.6000   73.0833     83.21        73
# 4                 port hardy  50.6996 -127.4199     42.58        82
# ..                       ...      ...       ...       ...       ...
# 555                   mehran  33.1222   46.1646     83.95        23
# 556               winchester  51.0651   -1.3187     58.53        33
# 557             vila do maio  15.1333  -23.2167     77.79        78
# 558                    alofi -19.0595 -169.9187     75.09        94
# 559  san carlos de bariloche -41.1456  -71.3082     70.45        45
#
#      Cloudiness  Wind Speed Country        Date
# 0            20       34.52      ZA  1682010976
# 1             0       11.50      US  1682011028
# 2           100        7.34      FR  1682011028
# 3            99        5.95      MV  1682011028
# 4           100       36.33      CA  1682010925
# ..          ...         ...     ...         ...
# 555         100        3.40      IR  1682011082
# 556           0       18.41      GB  1682011082
# 557          40       19.95      CV  1682011083
# 558         100       10.36      NU  1682011042
# 559           0        6.91      AR  1682011083
#
# [560 rows x 9 columns]

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port elizabeth -33.9180   25.5701     63.10        77          20
# 1        yarmouth  41.7057  -70.2286     57.96        56           0
# 2      bar-le-duc  48.7500    5.1667     42.22        95         100
# 3       hithadhoo  -0.6000   73.0833     83.21        73          99
# 4      port hardy  50.6996 -127.4199     42.58        82         100
#
#    Wind Speed Country        Date
# 0       34.52      ZA  1682010976
# 1       11.50      US  1682011028
# 2        7.34      FR  1682011028
# 3        5.95      MV  1682011028
# 4       36.33      CA  1682010925

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port elizabeth -33.9180   25.5701     63.10        77          20
# 1              yarmouth  41.7057  -70.2286     57.96        56           0
# 2            bar-le-duc  48.7500    5.1667     42.22        95         100
# 3             hithadhoo  -0.6000   73.0833     83.21        73          99
# 4            port hardy  50.6996 -127.4199     42.58        82         100
#
#          Wind Speed Country        Date
# City_ID
# 0             34.52      ZA  1682010976
# 1             11.50      US  1682011028
# 2              7.34      FR  1682011028
# 3              5.95      MV  1682011028
# 4             36.33      CA  1682010925

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x='Lat', y='Max Temp', c= 'DarkRed')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('Latitude vs Max Temperature (2023-01-02)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x='Lat', y='Humidity', c= 'DarkBlue')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs Humidity (2023-01-02)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x='Lat', y='Cloudiness', c= 'DarkGreen')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Latitude vs Cloudiness (2023-01-02)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x='Lat', y='Wind Speed', c= 'LightBlue')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Latitude vs Cloudiness (2023-01-02)')
plt.grid()


# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_regression(hemi,x,y,a,b):
    x_value = hemi[x]
    y_value = hemi[y]
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_value, y_value)
    regress_values = x_value * slope + intercept
    
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_value,y_value)
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")
    plt.plot(x_value,regress_values,"r-")
    print(f"The r-value is: {rvalue**2}")
    print(line_eq)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          yarmouth  41.7057  -70.2286     57.96        56           0
# 2        bar-le-duc  48.7500    5.1667     42.22        95         100
# 4        port hardy  50.6996 -127.4199     42.58        82         100
# 6           aklavik  68.2191 -135.0107     14.00        73          40
# 7            shingu  33.7333  135.9833     59.61        91         100
#
#          Wind Speed Country        Date
# City_ID
# 1             11.50      US  1682011028
# 2              7.34      FR  1682011028
# 4             36.33      CA  1682010925
# 6              4.61      CA  1682011029
# 7              4.65      JP  1682011029

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port elizabeth -33.9180  25.5701     63.10        77          20
# 3             hithadhoo  -0.6000  73.0833     83.21        73          99
# 5               humaita  -7.5061 -63.0208     88.54        63         100
# 8               ushuaia -54.8000 -68.3000     47.86        49          75
# 9                 ihosy -22.4000  46.1167     66.85        91          18
#
#          Wind Speed Country        Date
# City_ID
# 0             34.52      ZA  1682010976
# 3              5.95      MV  1682011028
# 5              2.66      BR  1682011029
# 8              4.61      AR  1682010826
# 9              3.15      MG  1682011029

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port elizabeth -33.9180  25.5701     63.10        77          20
# 3             hithadhoo  -0.6000  73.0833     83.21        73          99
# 5               humaita  -7.5061 -63.0208     88.54        63         100
# 8               ushuaia -54.8000 -68.3000     47.86        49          75
# 9                 ihosy -22.4000  46.1167     66.85        91          18
#
#          Wind Speed Country        Date
# City_ID
# 0             34.52      ZA  1682010976
# 3              5.95      MV  1682011028
# 5              2.66      BR  1682011029
# 8              4.61      AR  1682010826
# 9              3.15      MG  1682011029

# %%
# Linear regression on Northern Hemisphere
#lin_regression(northern_hemi_df,'Lat', 'Max Temp', 45,20)
#plt.xlabel('Latitude')
#plt.ylabel('Max Temp (C)')
#plt.show()

# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Max Temp']
y_values = northern_hemi_df["Lat"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=15,color="red")


plt.xlabel('Temperatures')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7275523383391348

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Max Temp']
y_values = southern_hemi_df["Lat"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(70,-50),fontsize=15,color="red")


plt.xlabel('Temperatures')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.489542237981069

# %% [markdown]
# **Discussion about the linear relationship:** As the latitude gets closer to 0 the more the temperature increases and as you get further away from 0 the more the temperature decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df['Humidity']
y_values = northern_hemi_df["Lat"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,5),fontsize=15,color="red")


plt.xlabel('Humidity')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0851261534160596

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Humidity']
y_values = southern_hemi_df["Lat"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")


plt.xlabel('Humidity')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.059788723071105984

# %% [markdown]
# **Discussion about the linear relationship:** As the latitude get closer to 0 there may be a possibility that humidity increases but keep in my that the r square isn't that high and the line is flatter in this scenario compared to the previous scenario about temperature.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Cloudiness']
y_values = northern_hemi_df["Lat"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")


plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.010106036258135087

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Cloudiness']
y_values = southern_hemi_df["Lat"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-50),fontsize=15,color="red")


plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.035040408384047435

# %% [markdown]
# **Discussion about the linear relationship:** The line is even flatter in this scenario. One could argure that as latitude increases the level of cloudiness has no impact. Additionally, I think other factor play a role in clouidness such as season and the level of humidity

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Wind Speed']
y_values = northern_hemi_df["Lat"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")


plt.xlabel('Wind Speed')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0008639127984262652

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Wind Speed']
y_values = southern_hemi_df["Lat"]


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-50),fontsize=15,color="red")


plt.xlabel('Wind Speed')
plt.ylabel('Latitude')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09242262414039394

# %% [markdown]
# **Discussion about the linear relationship:** According to the graph there is a closer relationship to wind speed as you go south away from the equator but I'm not confident that that's the true cause of windspeed. Additionally as you more north of the equator the line of best fit is flat so I don't think as you move away from the equator the level of wind speed will increase.
